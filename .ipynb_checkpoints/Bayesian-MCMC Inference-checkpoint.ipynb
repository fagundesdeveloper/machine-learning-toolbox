# %% [markdown]
# Provide a step by step basis for how to frame and ask quesitons in bayesian inference
#
# what is the probability distribution over some parameters (range) of a variable
#
# given a prior distribution (show with s plot) what is the likelihood function expressed as a bernouli distribution
#
# inculde measurements like the:
# hpd highest posterior density
# rope  region of practical equivalence
#
#
#
# show the differnce in prior distributions and the change in updating with more information

# %% [markdown]
# Neural network is a parameterized function- it has parameters,
#
# when we say bayesian we mean
# when dealing with parameter uncertainty and potentially structure uncertianty.
#
# bayes rule tells us how to do inference about hypothesis, uncertain quantities from data- measured quantities
#
# learning from prediction can ve seen as forms of inference
#
#
# latex this shit
# P(hypothesis|data) = P(hypothesis)P(data|hypothesis)/ sum(P(h)P(data|h)
#
# express our intial state of knowledgeabout the hypothesis as a probability distribution, that's the best way to represent uncertainty, that is the prior. And then the hypothesis can be evaluated by scoring the probability it gives that data given the hypothesis- that's called the likelihood. bayes rule says the way you combine the prior and the likelihood is you multiply them and renormalize over the space of plausable hypotheses you're considering - and that's learning- that's learning from data.
#
# //build a bayesian- ensemble model, and the d3/ dashboard should capture model complexity control and show "moving average" - I believe. - it should show how the model has calibrated itself over time. ( a figure that shows figure uncertainty)
#
# any well defined model can be bayesian -- any well defined model can be treated in a bayesian manner-
#
# mcmc sampling mehtod, hmc uses gradients to sample efficiently- on the back prop you use hmc and do a thing---gaussian processi
#
#
# Here is a great model for thinking about transformations in languages
#
# https://www.youtube.com/watch?v=v1BTHd5HXYE
#
# ![2017-09-03-00-10-www.youtube.com.png](attachment:2017-09-03-00-10-www.youtube.com.png)
#
# this guy and maybe some guide to ensembles
