# %% [markdown]
# ### Principal Component Analysis
#
# The purpose of principal component analysis is identify patterns to reduce the dimensions of the dataset with minimal loss of information.
#
# PCA uses an orthogonal transofrmaiton - a form of linear transformation
#
#
# PCA is a form of linear transformation, related to Multiple Discriminant Analysis(MDA).# perhaps more in a later part about mda and pca and the differences between them. Pca is often followed by mda
#
# In PCA were are ignoring class labels and projecting the entire set of data onto a different subspace to deistinguish between patterns that belong to different classes.

# %%
dimensions = d
projecting ontoa k dimensional space where k < d 
eigenvectors, eigenvalues, scatter-matrix, covariance matrix
mean vector, 
explain each of these first 
use the latex to show the composition of each process

# %%
import numpy as np

mu_vec1 = np.array([0,0,0]) #sample means
cov_mat1 = np.array([[1,0,0],[0,1,0],[0,0,1]]) #covariance matrix
class1_sample = np.random.multivariate_normal(mu_vec1, cov_mat1, 20).T

class1_sample
# Out:
# array([[ 1.20958584, -0.83008736, -0.7729999 , -1.86926936, -2.23399437,
#         -1.00184256, -1.46626777,  0.55678744, -0.01965652,  1.22812769,
#         -0.62596267,  0.29457485, -0.83925181,  0.69640322, -0.10871904,
#         -0.64209898, -1.00395076,  0.39877263, -0.21932133, -0.63426537],
#        [-0.23504916, -0.94678057, -0.84779926, -0.40777778, -1.02108445,
#         -1.04198917,  0.69717084,  0.68659321, -0.06797061,  0.96913403,
#          0.58322548,  1.49169556, -0.01858819,  1.21964313, -0.49758454,
#          0.70271551,  1.75468706, -0.12163468, -1.69649348,  1.24514704],
#        [ 0.4489631 ,  0.7166518 , -0.80656785, -0.33044874, -0.17788184,
#         -0.58858794,  0.26367026,  0.59865893,  0.16509983, -1.25419238,
#          0.83951373, -0.07517352, -0.65351991,  0.79486488,  0.82388004,
#         -0.1582381 , -1.80211921, -0.33117527,  0.13591254,  0.50773421]])

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d


fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
plt.rcParams['legend.fontsize'] = 10   
ax.plot(class1_sample[0,:], class1_sample[1,:], class1_sample[2,:], 'p', markersize=8, color='r', alpha=0.5, label='class1')
#ax.plot(class2_sample[0,:], class2_sample[1,:], class2_sample[2,:], '^', markersize=8, alpha=0.5, color='red', label='class2')

plt.title('Samples for class 1')
ax.legend(loc='upper right')

plt.show()

# %%
df = pd.read_csv(filename.tar.gz, compression='gzip', header=0, sep=',', quotechar='"')

# %%
fig,axes = plt.subplot(nrows= 3, ncols= 3)

for current_ax in axes: 
    current_ax.plot(x,y)
    
axes[0].plot(x,y)
.set_title
.

plt.tight_layout()

# %%
fig = plt.figure(figsize(8,2))
 
    
    
#plot appearance
# takes rgb hex codes
#

# %% [markdown]
# sometimes known as generl factor analysis
#
# it is an unsupervised algorithim
#
# we usually want to standardize our data by some scale for pca, so we'll cover how to do this as well
#
# where regression determines the line of best fit, the factor analysis determines several orthogonal lines of best fit to the data set,
#
#
# components are a linear transformation that chooses a variable system for the data set such that the greatest variance of the data set comes to lie on the first axis
#
#
#
# in the below example we are going to find which attributes explain the most variance in the dataset
#
# 1. is do pca first to get an idea of what's important in seeing what is malignant or benign

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np 
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import load_breast_cancer

# %%
cancer = load_breast_cancer()

# %%
type(cancer)
# Out:
# sklearn.datasets.base.Bunch

# %%
#print(cancer['DESCR'])

# %%
df = pd.DataFrame(cancer['data'], columns=cancer['feature_names'])

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension           ...             worst radius  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(df)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_data = scaler.transform(df)
scaled_data
# Out:
# array([[ 1.09706398, -2.07333501,  1.26993369, ...,  2.29607613,
#          2.75062224,  1.93701461],
#        [ 1.82982061, -0.35363241,  1.68595471, ...,  1.0870843 ,
#         -0.24388967,  0.28118999],
#        [ 1.57988811,  0.45618695,  1.56650313, ...,  1.95500035,
#          1.152255  ,  0.20139121],
#        ...,
#        [ 0.70228425,  2.0455738 ,  0.67267578, ...,  0.41406869,
#         -1.10454895, -0.31840916],
#        [ 1.83834103,  2.33645719,  1.98252415, ...,  2.28998549,
#          1.91908301,  2.21963528],
#        [-1.80840125,  1.22179204, -1.81438851, ..., -1.74506282,
#         -0.04813821, -0.75120669]])

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
pca.fit(scaled_data)
x_pca= pca.transform(scaled_data)
scaled_data.shape
x_pca.shape
# Out:
# (569, 2)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(x_pca[:, 0], x_pca[:, 1], c = cancer['target'], cmap='plasma')
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')

# %% [markdown]
# the components do not relate one to one to a specific feature in your data, the components are combinations of your features the components themselves are attributes of the pca object.
#
# in the component objects below we can see our components and their relationship to each of our 30 features

# %%
pca.components_
# Out:
# array([[ 0.21890244,  0.10372458,  0.22753729,  0.22099499,  0.14258969,
#          0.23928535,  0.25840048,  0.26085376,  0.13816696,  0.06436335,
#          0.20597878,  0.01742803,  0.21132592,  0.20286964,  0.01453145,
#          0.17039345,  0.15358979,  0.1834174 ,  0.04249842,  0.10256832,
#          0.22799663,  0.10446933,  0.23663968,  0.22487053,  0.12795256,
#          0.21009588,  0.22876753,  0.25088597,  0.12290456,  0.13178394],
#        [-0.23385713, -0.05970609, -0.21518136, -0.23107671,  0.18611302,
#          0.15189161,  0.06016536, -0.0347675 ,  0.19034877,  0.36657547,
#         -0.10555215,  0.08997968, -0.08945723, -0.15229263,  0.20443045,
#          0.2327159 ,  0.19720728,  0.13032156,  0.183848  ,  0.28009203,
#         -0.21986638, -0.0454673 , -0.19987843, -0.21935186,  0.17230435,
#          0.14359317,  0.09796411, -0.00825724,  0.14188335,  0.27533947]])

# %%
df_comp = pd.DataFrame(pca.components_, columns= cancer['feature_names'])
df_comp
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0     0.218902      0.103725        0.227537   0.220995         0.142590
# 1    -0.233857     -0.059706       -0.215181  -0.231077         0.186113
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0          0.239285        0.258400             0.260854       0.138167
# 1          0.151892        0.060165            -0.034768       0.190349
#
#    mean fractal dimension           ...             worst radius  \
# 0                0.064363           ...                 0.227997
# 1                0.366575           ...                -0.219866
#
#    worst texture  worst perimeter  worst area  worst smoothness  \
# 0       0.104469         0.236640    0.224871          0.127953
# 1      -0.045467        -0.199878   -0.219352          0.172304
#
#    worst compactness  worst concavity  worst concave points  worst symmetry  \
# ...
