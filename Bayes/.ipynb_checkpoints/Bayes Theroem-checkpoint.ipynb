# %% [markdown]
# # Bayes Theroem

# %% [markdown]
# $$ P(A|B) = \frac{P(B|A) * P(A)}{P(B)} $$

# %% [markdown]
# Example:
# Given two machines 1 and 2, machine 1 produces 30 wrenches and hour and machine 2 produces 20 wrenches an hour. In total 1% of parts are defective and if we were to pick out a part from the defective pile there is a 50% chance that it is from machine 1 and a 50% chance that it is from machine 2. What is the chance that a part from machine 2 being defective.
#
# Thus:
# - P(Mach2)=(20/50) = .4
# - P(Defect)=.01
# - P(Mach2|Defect) =.5
# - P(Defect|Mach2) = ?
#
#
# $$ P(Defect|Mach2)= \frac{P(Mach2|Defect) * P(Defect)}{P(Mach2)} $$
#
# $$ P(Defect|Mach2)= \frac{.5 * 0.01}{0.4}  = 0.0125 $$

# %% [markdown]
# # Naive Bayes Classifier Intuition

# %% [markdown]
# Given a two class classifier we can use the bayes theorem to generate the probability that someone of x features fits a class. Ex that given someone who exhibts X walks to work:
#
# ![2017-09-15-13-26-www.udemy.com.png](attachment:2017-09-15-13-26-www.udemy.com.png)
#
# It's important to get familiar with the lexicon, this will be used in all bayesian models. The numbers give us what order we should make our calculations.
#
# Given data for each of these calculations we can pick a point and show the probabalility that a point is of class walk and the chance that it is of class drive and then compare those two posterior probabilities.
#
# The Naice Bayes theorem is called Naive because it makes an assumption of independence, in that the independent variables we are using to predict a class have to be independent variables.
#
# In reality the features are often not independent or not completely independent.
